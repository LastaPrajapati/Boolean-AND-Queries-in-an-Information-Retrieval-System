# %% [markdown]
# Importing Libraries

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

import os
import string
import logging
import re
from collections import defaultdict, Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Define stopwords and lemmatizer
STOPWORDS = set(stopwords.words('english'))
LEMMATIZER = WordNetLemmatizer()

print("Libraries imported and resources downloaded successfully.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Libraries imported and resources downloaded successfully.

# %% [markdown]
# Loading Datasets

# %%
# Load the dataset (documents) from the text files
documents = []

# Generate file paths and open each document using a for loop
for i in range(1, 6):
    file_path = f'/content/review {i}.txt'
    with open(file_path, 'r') as file:
        documents.append(file.read())

# Print each document to verify it is loaded correctly
for i, doc in enumerate(documents, 1):
    print(f"Document {i}: {doc[:200]}...\n")  # Displaying only first 200 characters
# Out:
# Document 1: Queen Anne was the first ruler of the newly united Great Britain in the early 1700s; the last Stuart monarch before the Hanoverian dynasty that’s still with us (God save the Queen!). So, there’s your ...
#
# Document 2: Ethan Hunt and his slightly creaky IMF crew are on the trail of some plutonium before it finds its way into the hands of terrorists called The Apostles. They’re an offshoot of a group formed by Ethan’...
#
# Document 3: Since being hit by a mystic meteorite in ancient times, the African kingdom of Wakanda has developed a high-tech civilisation while maintaining traditional ways (spears, dancing, colourful clothing, s...
#
# Document 4:
# In a galaxy far, far away, for the past 40 years, the Rebel Alliance has kept destroying the evil Empire’s First Order’s big toys. But the Supreme Leader is still convinced a crushing victory is just...
#
# Document 5: The Perron family move into a large and run-down house – a deceased estate – in 1971 and discover that the deceased owners seem not to have moved out yet. Clocks stop, doors creak, things go bump in t...

# %% [markdown]
# Text Cleaning

# %%
# Function to clean and preprocess text (lowercase, tokenization, stopwords removal, and lemmatization)
def clean_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove non-alphabetic characters using regular expression
    text = re.sub(r'\W+', ' ', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords and lemmatize tokens
    tokens = [LEMMATIZER.lemmatize(token) for token in tokens if token not in STOPWORDS]

    return tokens

# Apply the cleaning function to each document in the dataset
cleaned_documents = [clean_text(doc) for doc in documents]

# Print the cleaned documents to verify
for i, doc in enumerate(cleaned_documents, 1):
    print(f"Cleaned Document {i}: {doc[:20]}...\n")  # Displaying only the first 20 tokens
# Out:
# Cleaned Document 1: ['queen', 'anne', 'first', 'ruler', 'newly', 'united', 'great', 'britain', 'early', '1700s', 'last', 'stuart', 'monarch', 'hanoverian', 'dynasty', 'still', 'u', 'god', 'save', 'queen']...
#
# Cleaned Document 2: ['ethan', 'hunt', 'slightly', 'creaky', 'imf', 'crew', 'trail', 'plutonium', 'find', 'way', 'hand', 'terrorist', 'called', 'apostle', 'offshoot', 'group', 'formed', 'ethan', 'old', 'adversary']...
#
# Cleaned Document 3: ['since', 'hit', 'mystic', 'meteorite', 'ancient', 'time', 'african', 'kingdom', 'wakanda', 'developed', 'high', 'tech', 'civilisation', 'maintaining', 'traditional', 'way', 'spear', 'dancing', 'colourful', 'clothing']...
#
# Cleaned Document 4: ['galaxy', 'far', 'far', 'away', 'past', '40', 'year', 'rebel', 'alliance', 'kept', 'destroying', 'evil', 'empire', 'first', 'order', 'big', 'toy', 'supreme', 'leader', 'still']...
#
# Cleaned Document 5: ['perron', 'family', 'move', 'large', 'run', 'house', 'deceased', 'estate', '1971', 'discover', 'deceased', 'owner', 'seem', 'moved', 'yet', 'clock', 'stop', 'door', 'creak', 'thing']...

# %% [markdown]
# NLTK Setup and Preprocessing

# %%
# Function to preprocess each document
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize the text into words
    words = word_tokenize(text)

    # Remove stopwords and lemmatize the words
    words = [LEMMATIZER.lemmatize(word) for word in words if word not in STOPWORDS and word.isalpha()]

    return words

# Apply preprocessing to each document in the collection
preprocessed_documents = [preprocess_text(doc) for doc in documents]

# Display preprocessed documents to check results
for i, doc in enumerate(preprocessed_documents, 1):
    print(f"Preprocessed Document {i}: {doc}\n")
# Out:
# Preprocessed Document 1: ['queen', 'anne', 'first', 'ruler', 'newly', 'united', 'great', 'britain', 'early', 'last', 'stuart', 'monarch', 'hanoverian', 'dynasty', 'still', 'u', 'god', 'save', 'queen', 'history', 'widowed', 'childless', 'semiinvalid', 'anne', 'lonely', 'eccentric', 'figure', 'stuck', 'gilded', 'cage', 'palace', 'leaf', 'managing', 'national', 'affair', 'childhood', 'friend', 'formidable', 'sarah', 'churchill', 'sarah', 'wife', 'john', 'churchill', 'head', 'armed', 'force', 'another', 'dynasty', 'still', 'u', 'duke', 'marlborough', 'john', 'also', 'known', 'fighting', 'french', 'comme', 'de', 'tradition', 'one', 'sarah', 'job', 'bully', 'parliament', 'keeping', 'war', 'funded', 'sarah', 'pretty', 'much', 'charge', 'arrival', 'impoverished', 'cousin', 'abigail', 'seek', 'work', 'servant', 'abigail', 'set', 'working', 'way', 'hierarchy', 'way', 'queen', 'bedchamber', 'witty', 'bawdy', 'occasionally', 'absurdist', 'story', 'court', 'politics', 'great', 'fun', 'despite', 'gratingly', 'annoying', 'music', 'probably', 'accurate', 'least', 'showing', 'fragile', 'power', 'social', 'status', 'era']
#
# Preprocessed Document 2: ['ethan', 'hunt', 'slightly', 'creaky', 'imf', 'crew', 'trail', 'plutonium', 'find', 'way', 'hand', 'terrorist', 'called', 'apostle', 'offshoot', 'group', 'formed', 'ethan', 'old', 'adversary', 'solomon', 'lane', 'remember', 'history', 'either', 'might', 'worth', 'renting', 'last', 'mi', 'film', 'rogue', 'nation', 'seeing', 'lane', 'currently', 'custody', 'long', 'eh', 'follows', 'chase', 'around', 'globe', 'usual', 'mi', 'recipe', 'added', 'complexity', 'multiple', 'player', 'one', 'scene', 'least', 'left', 'little', 'uncertain', 'shooting', 'upside', 'writerdirector', 'christopher', 'mcquarrie', 'delivers', 'plenty', 'visceral', 'action', 'genuine', 'tension', 'ethan', 'get', 'arse', 'kicked', 'early', 'fight', 'start', 'wonder', 'whether', 'ethan', 'might', 'finally', 'getting', 'vincible', 'yes', 'word', 'turn', 'tom', 'cruise', 'swansong', 'lead', 'role', 'though', 'bad', 'way', 'finish']
#
# Preprocessed Document 3: ['since', 'hit', 'mystic', 'meteorite', 'ancient', 'time', 'african', 'kingdom', 'wakanda', 'developed', 'hightech', 'civilisation', 'maintaining', 'traditional', 'way', 'spear', 'dancing', 'colourful', 'clothing', 'sexism', 'posing', 'rest', 'world', 'impoverished', 'third', 'world', 'country', 'challa', 'wakanda', 'new', 'king', 'following', 'father', 'untimely', 'death', 'previous', 'marvel', 'film', 'forget', 'king', 'also', 'black', 'panther', 'imbued', 'superhuman', 'strength', 'mystic', 'purple', 'blossom', 'yes', 'lot', 'prologue', 'challa', 'first', 'task', 'king', 'bring', 'father', 'killer', 'ulysses', 'klaue', 'justice', 'unfortunately', 'klaue', 'also', 'nicked', 'wakanda', 'mystic', 'meteorite', 'metal', 'used', 'develop', 'fiendish', 'weapon', 'threatens', 'reveal', 'wakanda', 'secret', 'world', 'challa', 'claw', 'full', 'thing', 'like', 'film', 'refreshing', 'nonwhiteness', 'main', 'female', 'character', 'moral', 'message', 'unfortunate', 'challa', 'simply', 'interesting', 'story', 'technology', 'fight', 'make', 'feel', 'like', 'composite', 'everything', 'iron', 'man', 'batman', 'bond', 'le', 'wit', 'also', 'far', 'long']
#
# Preprocessed Document 4: ['galaxy', 'far', 'far', 'away', 'past', 'year', 'rebel', 'alliance', 'kept', 'destroying', 'evil', 'empire', 'first', 'order', 'big', 'toy', 'supreme', 'leader', 'still', 'convinced', 'crushing', 'victory', 'around', 'corner', 'really', 'mate', 'time', 'negotiate', 'getting', 'younger', 'prettier', 'luke', 'skywalker', 'turned', 'hermit', 'remote', 'planet', 'happens', 'jedis', 'began', 'apparently', 'noone', 'thought', 'look', 'rey', 'woman', 'unknown', 'parentage', 'strange', 'affinity', 'force', 'arrives', 'coax', 'back', 'fight', 'meanwhile', 'first', 'order', 'fleet', 'chasing', 'rebel', 'mothership', 'sort', 'lowspeed', 'space', 'car', 'chase', 'need', 'stifle', 'technological', 'question', 'later', 'galactic', 'superpower', 'build', 'planetmelting', 'death', 'ray', 'trouble', 'breaking', 'single', 'blast', 'door', 'speeder', 'fly', 'long', 'without', 'apparently', 'getting', 'anywhere', 'otherwise', 'pacy', 'witty', 'film', 'creatively', 'expands', 'storyworld', 'still', 'keeping', 'fan', 'happy', 'emotional', 'resonance', 'heightened', 'carrie', 'fisher', 'last', 'turn', 'leia', 'even', 'asks', 'question', 'really', 'benefit', 'war']
#
# Preprocessed Document 5: ['perron', 'family', 'move', 'large', 'rundown', 'house', 'deceased', 'estate', 'discover', 'deceased', 'owner', 'seem', 'moved', 'yet', 'clock', 'stop', 'door', 'creak', 'thing', 'go', 'bump', 'night', 'various', 'perrons', 'get', 'thumped', 'night', 'etc', 'tired', 'demonised', 'call', 'demonologists', 'ed', 'lorraine', 'warren', 'usual', 'hauntedhouse', 'shenanigan', 'ensue', 'supposedly', 'based', 'true', 'story', 'possibly', 'explains', 'thing', 'get', 'extreme', 'fact', 'bit', 'slow', 'time', 'script', 'somewhat', 'clunky', 'lack', 'central', 'character', 'make', 'hard', 'engage', 'chill', 'like', 'horror', 'retroflavoured']

# %% [markdown]
# Inverted Index Construction

# %%
# Function to construct the inverted index
def build_inverted_index(docs):
    inverted_index = defaultdict(list)

    # Iterate over each document
    for doc_id, doc in enumerate(docs):
        # Count word frequency in the document
        word_freq = Counter(doc)

        # Add each word to the inverted index with its document ID
        for word in word_freq:
            inverted_index[word].append(doc_id)

    return inverted_index

# Build the inverted index from the preprocessed documents
inverted_index = build_inverted_index(preprocessed_documents)

# Display the inverted index
print("Inverted Index:")
for word, doc_ids in inverted_index.items():
    print(f"{word}: {doc_ids}")
# Out:
# Inverted Index:
# queen: [0]
# anne: [0]
# first: [0, 2, 3]
# ruler: [0]
# newly: [0]
# united: [0]
# great: [0]
# britain: [0]
# early: [0, 1]
# last: [0, 1, 3]
# stuart: [0]
# monarch: [0]
# hanoverian: [0]
# dynasty: [0]
# still: [0, 3]
# u: [0]
# god: [0]
# save: [0]
# history: [0, 1]
# widowed: [0]
# childless: [0]
# semiinvalid: [0]
# lonely: [0]
# eccentric: [0]
# figure: [0]
# stuck: [0]
# gilded: [0]
# cage: [0]
# palace: [0]
# leaf: [0]
# managing: [0]
# national: [0]
# affair: [0]
# childhood: [0]
# friend: [0]
# formidable: [0]
# sarah: [0]
# churchill: [0]
# wife: [0]
# john: [0]
# head: [0]
# armed: [0]
# force: [0, 3]
# another: [0]
# duke: [0]
# marlborough: [0]
# also: [0, 2]
# known: [0]
# fighting: [0]
# french: [0]
# comme: [0]
# de: [0]
# tradition: [0]
# one: [0, 1]
# job: [0]
# bully: [0]
# parliament: [0]
# keeping: [0, 3]
# war: [0, 3]
# funded: [0]
# pretty: [0]
# much: [0]
# charge: [0]
# arrival: [0]
# impoverished: [0, 2]
# cousin: [0]
# abigail: [0]
# seek: [0]
# work: [0]
# servant: [0]
# set: [0]
# working: [0]
# way: [0, 1, 2]
# hierarchy: [0]
# bedchamber: [0]
# witty: [0, 3]
# bawdy: [0]
# occasionally: [0]
# absurdist: [0]
# story: [0, 2, 4]
# court: [0]
# politics: [0]
# fun: [0]
# despite: [0]
# gratingly: [0]
# annoying: [0]
# music: [0]
# probably: [0]
# accurate: [0]
# least: [0, 1]
# showing: [0]
# fragile: [0]
# power: [0]
# social: [0]
# status: [0]
# era: [0]
# ethan: [1]
# hunt: [1]
# slightly: [1]
# creaky: [1]
# imf: [1]
# crew: [1]
# trail: [1]
# plutonium: [1]
# find: [1]
# hand: [1]
# terrorist: [1]
# called: [1]
# apostle: [1]
# offshoot: [1]
# group: [1]
# formed: [1]
# old: [1]
# adversary: [1]
# solomon: [1]
# lane: [1]
# remember: [1]
# either: [1]
# might: [1]
# worth: [1]
# renting: [1]
# mi: [1]
# film: [1, 2, 3]
# rogue: [1]
# nation: [1]
# seeing: [1]
# currently: [1]
# custody: [1]
# long: [1, 2, 3]
# eh: [1]
# follows: [1]
# chase: [1, 3]
# around: [1, 3]
# globe: [1]
# usual: [1, 4]
# recipe: [1]
# added: [1]
# complexity: [1]
# multiple: [1]
# player: [1]
# scene: [1]
# left: [1]
# little: [1]
# uncertain: [1]
# shooting: [1]
# upside: [1]
# writerdirector: [1]
# christopher: [1]
# mcquarrie: [1]
# delivers: [1]
# plenty: [1]
# visceral: [1]
# action: [1]
# genuine: [1]
# tension: [1]
# get: [1, 4]
# arse: [1]
# kicked: [1]
# fight: [1, 2, 3]
# start: [1]
# wonder: [1]
# whether: [1]
# finally: [1]
# getting: [1, 3]
# vincible: [1]
# yes: [1, 2]
# word: [1]
# turn: [1, 3]
# tom: [1]
# cruise: [1]
# swansong: [1]
# lead: [1]
# role: [1]
# though: [1]
# bad: [1]
# finish: [1]
# since: [2]
# hit: [2]
# mystic: [2]
# meteorite: [2]
# ancient: [2]
# time: [2, 3, 4]
# african: [2]
# kingdom: [2]
# wakanda: [2]
# developed: [2]
# hightech: [2]
# civilisation: [2]
# maintaining: [2]
# traditional: [2]
# spear: [2]
# dancing: [2]
# colourful: [2]
# clothing: [2]
# sexism: [2]
# posing: [2]
# rest: [2]
# world: [2]
# third: [2]
# country: [2]
# challa: [2]
# new: [2]
# king: [2]
# following: [2]
# father: [2]
# untimely: [2]
# death: [2, 3]
# previous: [2]
# marvel: [2]
# forget: [2]
# black: [2]
# panther: [2]
# imbued: [2]
# superhuman: [2]
# strength: [2]
# purple: [2]
# blossom: [2]
# lot: [2]
# prologue: [2]
# task: [2]
# bring: [2]
# killer: [2]
# ulysses: [2]
# klaue: [2]
# justice: [2]
# unfortunately: [2]
# nicked: [2]
# metal: [2]
# used: [2]
# develop: [2]
# fiendish: [2]
# weapon: [2]
# threatens: [2]
# reveal: [2]
# secret: [2]
# claw: [2]
# full: [2]
# thing: [2, 4]
# like: [2, 4]
# refreshing: [2]
# nonwhiteness: [2]
# main: [2]
# female: [2]
# character: [2, 4]
# moral: [2]
# message: [2]
# unfortunate: [2]
# simply: [2]
# interesting: [2]
# technology: [2]
# make: [2, 4]
# feel: [2]
# composite: [2]
# everything: [2]
# iron: [2]
# man: [2]
# batman: [2]
# bond: [2]
# le: [2]
# wit: [2]
# far: [2, 3]
# galaxy: [3]
# away: [3]
# past: [3]
# year: [3]
# rebel: [3]
# alliance: [3]
# kept: [3]
# destroying: [3]
# evil: [3]
# empire: [3]
# order: [3]
# big: [3]
# toy: [3]
# supreme: [3]
# leader: [3]
# convinced: [3]
# crushing: [3]
# victory: [3]
# corner: [3]
# really: [3]
# mate: [3]
# negotiate: [3]
# younger: [3]
# prettier: [3]
# luke: [3]
# skywalker: [3]
# turned: [3]
# hermit: [3]
# remote: [3]
# planet: [3]
# happens: [3]
# jedis: [3]
# began: [3]
# apparently: [3]
# noone: [3]
# thought: [3]
# look: [3]
# rey: [3]
# woman: [3]
# unknown: [3]
# parentage: [3]
# strange: [3]
# affinity: [3]
# arrives: [3]
# coax: [3]
# back: [3]
# meanwhile: [3]
# fleet: [3]
# chasing: [3]
# mothership: [3]
# sort: [3]
# lowspeed: [3]
# space: [3]
# car: [3]
# need: [3]
# stifle: [3]
# technological: [3]
# question: [3]
# later: [3]
# galactic: [3]
# superpower: [3]
# build: [3]
# planetmelting: [3]
# ray: [3]
# trouble: [3]
# breaking: [3]
# single: [3]
# blast: [3]
# door: [3, 4]
# speeder: [3]
# fly: [3]
# without: [3]
# anywhere: [3]
# otherwise: [3]
# pacy: [3]
# creatively: [3]
# expands: [3]
# storyworld: [3]
# fan: [3]
# happy: [3]
# emotional: [3]
# resonance: [3]
# heightened: [3]
# carrie: [3]
# fisher: [3]
# leia: [3]
# even: [3]
# asks: [3]
# benefit: [3]
# perron: [4]
# family: [4]
# move: [4]
# large: [4]
# rundown: [4]
# house: [4]
# deceased: [4]
# estate: [4]
# discover: [4]
# owner: [4]
# seem: [4]
# moved: [4]
# yet: [4]
# clock: [4]
# stop: [4]
# creak: [4]
# go: [4]
# bump: [4]
# night: [4]
# various: [4]
# perrons: [4]
# thumped: [4]
# etc: [4]
# tired: [4]
# demonised: [4]
# call: [4]
# demonologists: [4]
# ed: [4]
# lorraine: [4]
# warren: [4]
# hauntedhouse: [4]
# shenanigan: [4]
# ensue: [4]
# supposedly: [4]
# based: [4]
# true: [4]
# possibly: [4]
# explains: [4]
# extreme: [4]
# fact: [4]
# bit: [4]
# slow: [4]
# script: [4]
# somewhat: [4]
# clunky: [4]
# lack: [4]
# central: [4]
# hard: [4]
# engage: [4]
# chill: [4]
# horror: [4]
# retroflavoured: [4]

# %% [markdown]
# Boolean Query Operation (AND Operation)

# %%
# Assuming 'documents' is a dictionary with filenames as keys and preprocessed text as values
# Initialize all_documents with the set of all document IDs
all_documents = set(range(len(documents)))  # If your documents are indexed as 0, 1, 2, ...

# Function for 'AND' query (finds common documents for all terms)
def and_query(terms, inverted_index):
    # Get the initial set of documents that contain the first term
    result = set(inverted_index.get(terms[0], set()))

    # Perform intersection with the document sets for the remaining terms
    for term in terms[1:]:
        result &= set(inverted_index.get(term, set()))  # Intersection with the next term's documents

    return result

# Example usage:
query = "king war"  # Example query
query_terms = preprocess_text(query)  # Preprocess query to get terms

# Perform AND query using the terms
result_docs = and_query(query_terms, inverted_index)

# Display the results
print(f"Documents matching '{query}' using AND operation: {result_docs}")
# Out:
# Documents matching 'king war' using AND operation: set()

# %% [markdown]
# Convert doc_ids to File Names

# %%
# Mapping document IDs to their respective file names
doc_id_to_filename = {
    0: 'review1.txt',
    1: 'review2.txt',
    2: 'review3.txt',
    3: 'review4.txt',
    4: 'review5.txt'
}

# Function to convert doc_ids to file names
def convert_doc_ids_to_filenames(doc_ids):
    return [doc_id_to_filename[doc_id] for doc_id in doc_ids]

# Example: Convert doc_ids from an AND query to file names
query_terms = ['king', 'war']  # Example terms for AND query
result_docs = and_query(query_terms, inverted_index)
result_filenames = convert_doc_ids_to_filenames(result_docs)

# Display the result
print(f"Documents matching AND query {query_terms}: {result_filenames}")
# Out:
# Documents matching AND query ['king', 'war']: []

# %% [markdown]
# Main Function

# %%
# Main function to run the entire process
def main():

    # Step 2: Preprocess the documents
    cleaned_documents = [preprocess_text(doc) for doc in documents]

    # Step 3: Build the inverted index
    inverted_index = build_inverted_index(cleaned_documents)

    # Step 4: Perform AND query processing
    query_terms = ['king', 'war']  # Example terms for AND query
    result_docs = and_query(query_terms, inverted_index)
    result_filenames = convert_doc_ids_to_filenames(result_docs)
    print(f"Documents matching AND query {query_terms}: {result_filenames}")

# Call the main function to run everything
if __name__ == "__main__":
    main()
# Out:
# Documents matching AND query ['king', 'war']: []

# %%
# Function to write query results to a file, including the author name
def write_results_to_file(results, output_file):
    with open(output_file, 'w') as file:
        # Write the name at the top of the file
        file.write("Reviews by Lasta\n\n")

        # Write the query results
        for result in results:
            file.write(result + '\n')

# Example: Process the query and write results to a file
def process_query(query, inverted_index, documents):
    # Split the query into terms
    query_terms = query.split()

    # Perform the Boolean AND query
    query_results_docs = boolean_and_query(query_terms, inverted_index)

    # Convert document IDs to filenames
    query_results_filenames = convert_doc_ids_to_filenames(query_results_docs)

    # Write the results to a file
    write_results_to_file(query_results_filenames, 'query_results.txt')

    return query_results_filenames

# %% [markdown]
# Reverse Dictionary

# %%
import os
from collections import defaultdict

# Specify the directory containing the text files
directory = '/content/'

# Step 1: Load the dataset (documents) from the text files in the directory
documents = []
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        with open(os.path.join(directory, filename), 'r') as file:
            documents.append(file.read())

# Step 2: Preprocess the text (tokenization and cleaning)
def preprocess_text(text):
    # Convert to lowercase, remove special characters, tokenize, etc.
    tokens = text.lower().split()
    return tokens

# Step 3: Build the inverted index and reverse dictionary
inverted_index = defaultdict(set)
reverse_dictionary = defaultdict(set)

for doc_id, doc in enumerate(documents):
    tokens = preprocess_text(doc)
    for token in tokens:
        inverted_index[token].add(doc_id)
        reverse_dictionary[doc_id].add(token)

# Step 4: Print the inverted index (term to document mapping)
print("Inverted Index:")
for term, doc_ids in inverted_index.items():
    print(f"{term}: {doc_ids}")

# Step 5: Print the reverse dictionary (document to term mapping)
print("\nReverse Dictionary:")
for doc_id, terms in reverse_dictionary.items():
    print(f"Document {doc_id}: {terms}")
# Out:
# Inverted Index:
# the: {0, 1, 2, 3, 4}
# perron: {0}
# family: {0}
# move: {0}
# into: {0, 1, 2, 3}
# a: {0, 1, 2, 3, 4}
# large: {0}
# and: {0, 1, 2, 3, 4}
# run-down: {0}
# house: {0}
# –: {0, 2}
# deceased: {0}
# estate: {0}
# in: {0, 1, 2, 3, 4}
# 1971: {0}
# discover: {0}
# that: {0, 1, 2, 4}
# owners: {0}
# seem: {0}
# not: {0, 2, 4}
# to: {0, 1, 2, 3, 4}
# have: {0}
# moved: {0}
# out: {0, 3}
# yet.: {0}
# clocks: {0}
# stop,: {0}
# doors: {0}
# creak,: {0}
# things: {0, 4}
# go: {0}
# bump: {0}
# night,: {0}
# various: {0}
# perrons: {0}
# get: {0}
# thumped: {0}
# etc.: {0}
# tired: {0}
# of: {0, 1, 2, 3, 4}
# being: {0, 4}
# demonised,: {0}
# they: {0}
# call: {0}
# demonologists: {0}
# ed: {0}
# lorraine: {0}
# warren.: {0}
# usual: {0, 3}
# haunted-house: {0}
# shenanigans: {0}
# ensue.: {0}
# this: {0, 1, 2, 3, 4}
# is: {0, 1, 2, 3, 4}
# supposedly: {0}
# based: {0}
# on: {0, 2, 3}
# true: {0}
# story,: {0, 4}
# which: {0}
# possibly: {0}
# explains: {0}
# why: {0, 2}
# don’t: {0}
# too: {0, 4}
# extreme.: {0}
# fact: {0}
# it’s: {0, 2, 3, 4}
# bit: {0}
# slow: {0}
# at: {0, 3}
# times,: {0, 4}
# script: {0}
# somewhat: {0}
# clunky,: {0}
# lack: {0}
# central: {0}
# character: {0}
# makes: {0}
# it: {0, 2, 3, 4}
# hard: {0}
# engage: {0}
# with.: {0}
# but: {0, 2, 3, 4}
# does: {0, 3}
# few: {0, 2}
# chills: {0}
# for: {0, 2, 3}
# those: {0}
# who: {0, 1, 2, 3}
# like: {0, 4}
# their: {0, 3}
# horror: {0}
# retro-flavoured.: {0}
# queen: {1}
# anne: {1}
# was: {1, 3}
# first: {1, 2, 4}
# ruler: {1}
# newly: {1}
# united: {1}
# great: {1}
# britain: {1}
# early: {1, 3}
# 1700s;: {1}
# last: {1, 2, 3}
# stuart: {1}
# monarch: {1}
# before: {1, 3}
# hanoverian: {1}
# dynasty: {1}
# that’s: {1}
# still: {1, 2}
# with: {1, 2, 3, 4}
# us: {1}
# (god: {1}
# save: {1}
# queen!).: {1}
# so,: {1}
# there’s: {1, 4}
# your: {1, 2}
# history.: {1}
# here,: {1}
# widowed,: {1}
# childless,: {1}
# semi-invalid: {1}
# lonely,: {1}
# eccentric: {1}
# figure,: {1}
# stuck: {1}
# gilded: {1}
# cage: {1}
# her: {1}
# palace,: {1}
# leaves: {1}
# managing: {1}
# national: {1}
# affairs: {1}
# childhood: {1}
# friend,: {1}
# formidable: {1}
# sarah: {1}
# churchill.: {1}
# wife: {1}
# john: {1}
# churchill,: {1}
# head: {1}
# armed: {1}
# forces: {1}
# (and: {1}
# another: {1}
# us).: {1}
# duke: {1}
# marlborough,: {1}
# as: {1, 2, 4}
# also: {1, 4}
# known,: {1}
# off: {1}
# fighting: {1}
# french,: {1}
# comme: {1}
# de: {1}
# tradition,: {1}
# one: {1, 3}
# sarah’s: {1}
# jobs: {1}
# bully: {1}
# parliament: {1}
# keeping: {1, 2}
# his: {1, 3, 4}
# war: {1}
# funded.: {1}
# sarah,: {1}
# then,: {1}
# pretty: {1}
# much: {1}
# charge: {1}
# until: {1, 2}
# arrival: {1}
# impoverished: {1, 4}
# cousin,: {1}
# abigail,: {1}
# seeks: {1}
# work: {1}
# servant.: {1}
# abigail: {1}
# then: {1}
# sets: {1}
# about: {1, 2, 3, 4}
# working: {1}
# way: {1, 3}
# up: {1}
# hierarchy,: {1}
# all: {1}
# queen’s: {1}
# bedchamber.: {1}
# witty,: {1}
# bawdy: {1}
# occasionally: {1}
# absurdist: {1}
# story: {1}
# court: {1}
# politics: {1}
# fun: {1}
# (despite: {1}
# some: {1, 3, 4}
# gratingly: {1}
# annoying: {1}
# music): {1}
# probably: {1}
# accurate: {1}
# (at: {1}
# least): {1}
# showing: {1}
# how: {1, 2, 3}
# fragile: {1}
# both: {1}
# power: {1}
# social: {1}
# status: {1}
# were: {1}
# era.: {1}
# galaxy: {2}
# far,: {2}
# far: {2, 4}
# away,: {2}
# past: {2}
# 40: {2}
# years,: {2}
# rebel: {2}
# alliance: {2}
# has: {2, 4}
# kept: {2}
# destroying: {2}
# evil: {2}
# empire’s: {2}
# order’s: {2}
# big: {2}
# toys.: {2}
# supreme: {2}
# leader: {2}
# convinced: {2}
# crushing: {2}
# victory: {2}
# just: {2, 4}
# around: {2, 3}
# corner.: {2}
# really,: {2}
# mate,: {2}
# time: {2}
# negotiate.: {2}
# you’re: {2}
# getting: {2, 3}
# any: {2}
# younger: {2}
# or: {2}
# prettier.: {2}
# luke: {2}
# skywalker: {2}
# turned: {2}
# hermit: {2}
# remote: {2}
# planet: {2}
# happens: {2}
# be: {2, 3}
# where: {2}
# jedis: {2}
# began.: {2}
# apparently: {2}
# no-one: {2}
# thought: {2}
# look: {2}
# him: {2}
# there: {2, 4}
# rey,: {2}
# woman: {2}
# unknown: {2}
# parentage: {2}
# strange: {2}
# affinity: {2}
# force,: {2}
# arrives: {2}
# coax: {2}
# back: {2}
# fight.: {2}
# meanwhile,: {2}
# order: {2}
# fleet: {2}
# chasing: {2}
# mothership: {2}
# sort: {2}
# low-speed: {2}
# space: {2}
# car: {2}
# chase.: {2}
# (you’ll: {2}
# need: {2}
# stifle: {2}
# technological: {2}
# questions: {2}
# such: {2}
# as,: {2}
# later,: {2}
# galactic: {2}
# superpower: {2}
# can: {2}
# build: {2}
# planet-melting: {2}
# death: {2, 4}
# ray: {2}
# trouble: {2}
# breaking: {2}
# down: {2}
# single: {2}
# blast: {2}
# door,: {2}
# speeders: {2}
# fly: {2}
# so: {2, 4}
# long: {2}
# without: {2}
# anywhere.): {2}
# otherwise,: {2}
# pacy,: {2}
# witty: {2}
# film: {2, 4}
# creatively: {2}
# expands: {2}
# storyworld: {2}
# while: {2, 4}
# fans: {2}
# happy.: {2}
# an: {2, 3, 4}
# emotional: {2}
# resonance: {2}
# heightened: {2}
# by: {2, 3, 4}
# carrie: {2}
# fisher’s: {2}
# turn: {2, 3}
# leia: {2}
# even: {2}
# asks: {2}
# really: {2}
# benefits: {2}
# from: {2, 4}
# war.: {2}
# ethan: {3}
# hunt: {3}
# slightly: {3}
# creaky: {3}
# imf: {3}
# crew: {3}
# are: {3, 4}
# trail: {3}
# plutonium: {3}
# finds: {3}
# its: {3, 4}
# hands: {3}
# terrorists: {3}
# called: {3}
# apostles.: {3}
# they’re: {3}
# offshoot: {3}
# group: {3}
# formed: {3}
# ethan’s: {3}
# old: {3}
# adversary: {3}
# solomon: {3}
# lane.: {3}
# no,: {3}
# i: {3}
# couldn’t: {3}
# remember: {3}
# history: {3}
# either:: {3}
# might: {3}
# worth: {3}
# renting: {3}
# m:i: {3}
# film,: {3}
# rogue: {3}
# nation,: {3}
# seeing: {3}
# this.: {3}
# lane: {3}
# currently: {3}
# custody,: {3}
# long,: {3}
# eh?: {3}
# what: {3}
# follows: {3}
# chase: {3}
# globe: {3}
# recipe,: {3}
# added: {3}
# complexity: {3}
# multiple: {3}
# players: {3}
# that,: {3, 4}
# scene: {3}
# least,: {3}
# left: {3}
# me: {3}
# little: {3}
# uncertain: {3}
# shooting: {3}
# whom.: {3}
# upside,: {3}
# writer-director: {3}
# christopher: {3}
# mcquarrie: {3}
# delivers: {3}
# plenty: {3}
# visceral: {3}
# action: {3}
# genuine: {3}
# tension.: {3}
# when: {3}
# gets: {3}
# arse: {3}
# kicked: {3}
# fight,: {3}
# we: {3}
# start: {3}
# wonder: {3}
# whether: {3}
# finally: {3}
# vincible: {3}
# (yes,: {3, 4}
# word).: {3}
# if: {3}
# tom: {3}
# cruise’s: {3}
# swansong: {3}
# lead: {3}
# role,: {3}
# though,: {3}
# wouldn’t: {3}
# bad: {3}
# finish.: {3}
# since: {4}
# hit: {4}
# mystic: {4}
# meteorite: {4}
# ancient: {4}
# african: {4}
# kingdom: {4}
# wakanda: {4}
# developed: {4}
# high-tech: {4}
# civilisation: {4}
# maintaining: {4}
# traditional: {4}
# ways: {4}
# (spears,: {4}
# dancing,: {4}
# colourful: {4}
# clothing,: {4}
# sexism): {4}
# posing: {4}
# rest: {4}
# world: {4}
# third: {4}
# country.: {4}
# t’challa: {4}
# wakanda’s: {4}
# new: {4}
# king: {4}
# following: {4}
# father’s: {4}
# untimely: {4}
# previous: {4}
# marvel: {4}
# (i: {4}
# forget: {4}
# which).: {4}
# black: {4}
# panther,: {4}
# imbued: {4}
# superhuman: {4}
# strength: {4}
# purple: {4}
# blossom: {4}
# lots: {4}
# prologue: {4}
# this).: {4}
# t’challa’s: {4}
# task: {4}
# bring: {4}
# killer,: {4}
# ulysses: {4}
# klaue,: {4}
# justice.: {4}
# unfortunately: {4}
# klaue: {4}
# nicked: {4}
# metal: {4}
# used: {4}
# develop: {4}
# fiendish: {4}
# weapons.: {4}
# only: {4}
# he: {4}
# threatens: {4}
# reveal: {4}
# secret: {4}
# world.: {4}
# claws: {4}
# full.: {4}
# film.: {4}
# refreshing: {4}
# non-whiteness,: {4}
# main: {4}
# female: {4}
# characters,: {4}
# moral: {4}
# message.: {4}
# unfortunate: {4}
# simply: {4}
# isn’t: {4}
# very: {4}
# interesting: {4}
# technology: {4}
# fights: {4}
# make: {4}
# feel: {4}
# composite: {4}
# everything: {4}
# iron: {4}
# man: {4}
# batman: {4}
# bond,: {4}
# less: {4}
# wit.: {4}
# long.: {4}
#
# Reverse Dictionary:
# Document 0: {'but', 'which', 'perrons', 'go', 'various', 'being', 'warren.', 'explains', 'too', 'creak,', 'not', 'ensue.', 'somewhat', 'character', 'don’t', 'based', 'stop,', 'doors', 'at', 'it', 'horror', 'estate', 'clunky,', 'those', 'like', 'possibly', 'yet.', 'slow', 'it’s', 'lorraine', 'of', 'lack', '1971', 'with.', 'to', 'this', 'why', 'seem', 'is', 'house', 'things', 'for', '–', 'have', 'run-down', 'get', 'their', 'night,', 'into', 'moved', 'discover', 'etc.', 'who', 'story,', 'script', 'demonised,', 'large', 'deceased', 'call', 'bump', 'times,', 'extreme.', 'chills', 'and', 'makes', 'in', 'shenanigans', 'usual', 'hard', 'central', 'the', 'fact', 'demonologists', 'tired', 'true', 'move', 'few', 'owners', 'thumped', 'haunted-house', 'clocks', 'engage', 'on', 'retro-flavoured.', 'ed', 'that', 'supposedly', 'family', 'a', 'they', 'bit', 'does', 'perron', 'out'}
# Document 1: {'dynasty', 'impoverished', 'showing', 'semi-invalid', 'french,', 'working', 'head', 'forces', 'churchill,', 'so,', 'marlborough,', 'there’s', 'before', 'great', 'fighting', 'all', 'least)', 'music)', 'work', 'about', 'your', 'another', 'friend,', 'abigail,', 'cousin,', 'churchill.', 'queen', 'stuck', 'bedchamber.', 'sarah’s', 'much', 'still', 'abigail', 'leaves', 'affairs', 'figure,', 'story', 'queen!).', 'first', 'save', 'jobs', 'politics', 'of', 'armed', 'parliament', '(despite', 'social', 'childhood', 'funded.', 'to', 'this', '1700s;', 'is', 'gilded', 'wife', 'britain', 'newly', 'arrival', 'era.', 'early', 'charge', 'one', 'sarah', 'keeping', 'comme', 'into', 'way', 'here,', 'power', 'status', 'national', 'who', 'how', 'cage', 'history.', 'annoying', 'monarch', 'john', 'witty,', 'with', 'also', '(and', 'occasionally', 'ruler', 'childless,', 'accurate', 'probably', 'managing', 'then', 'was', 'gratingly', 'her', 'duke', 'formidable', 'us).', 'eccentric', 'and', 'hanoverian', 'in', 'tradition,', 'as', 'up', 'pretty', 'fragile', 'the', 'hierarchy,', 'fun', 'stuart', 'sarah,', 'that’s', 'united', 'absurdist', 'seeks', 'us', 'last', 'both', 'lonely,', 'de', 'until', 'known,', '(god', 'servant.', 'were', 'court', 'his', 'sets', 'that', 'queen’s', 'widowed,', 'then,', 'bawdy', 'palace,', 'war', 'anne', 'a', 'off', 'bully', 'some', '(at'}
# Document 2: {'but', 'later,', 'around', 'supreme', 'jedis', 'negotiate.', 'look', 'car', 'thought', 'planet', 'not', 'planet-melting', 'past', 'while', 'rey,', 'corner.', 'it', 'fisher’s', 'down', 'where', 'began.', 'about', 'your', 'anywhere.)', 'war.', 'heightened', 'asks', 'single', 'otherwise,', 'superpower', 'sort', 'alliance', 'prettier.', 'leader', 'far', 'still', 'him', 'skywalker', 'happy.', 'hermit', 'it’s', 'empire’s', 'or', 'carrie', 'first', 'order', 'any', 'as,', 'door,', 'time', 'of', 'death', 'can', 'such', 'really,', 'to', 'why', 'this', 'destroying', 'is', '40', 'remote', 'build', 'turn', 'for', 'unknown', '–', 'from', 'be', 'expands', 'benefits', 'keeping', 'force,', 'into', 'emotional', 'who', 'how', 'even', 'chasing', 'ray', 'with', 'witty', 'apparently', 'fleet', 'resonance', 'mate,', 'away,', 'years,', 'you’re', 'need', 'fight.', 'questions', 'storyworld', 'rebel', 'luke', 'and', 'happens', 'really', 'in', 'arrives', 'younger', 'as', 'kept', 'mothership', 'chase.', 'the', 'breaking', 'coax', 'there', 'victory', 'fly', 'affinity', 'strange', 'low-speed', 'order’s', 'back', 'creatively', 'parentage', 'getting', 'an', 'film', '(you’ll', 'speeders', 'technological', 'last', 'leia', 'stifle', 'fans', 'few', 'meanwhile,', 'just', 'pacy,', 'no-one', 'woman', 'trouble', 'crushing', 'big', 'until', 'galactic', 'has', 'space', 'convinced', 'on', 'toys.', 'far,', 'evil', 'that', 'by', 'galaxy', 'a', 'turned', 'long', 'without', 'so', 'blast'}
# Document 3: {'they’re', 'but', 'rogue', 'around', 'scene', 'left', 'tom', 'either:', 'seeing', 'plutonium', 'players', 'genuine', 'swansong', 'lead', 'me', 'cruise’s', 'mcquarrie', 'before', 'it', 'at', 'writer-director', 'currently', 'little', 'about', 'creaky', 'vincible', 'tension.', 'finally', 'adversary', 'whether', 'this.', 'least,', 'fight,', '(yes,', 'nation,', 'christopher', 'role,', 'terrorists', 'film,', 'start', 'upside,', 'it’s', 'chase', 'are', 'of', 'apostles.', 'that,', 'might', 'action', 'arse', 'added', 'multiple', 'finds', 'to', 'this', 'renting', 'is', 'turn', 'for', 'plenty', 'history', 'early', 'their', 'be', 'one', 'into', 'way', 'if', 'who', 'how', 'group', 'trail', 'solomon', 'delivers', 'gets', 'eh?', 'hands', 'ethan', 'follows', 'with', 'wouldn’t', 'hunt', 'shooting', 'no,', 'we', 'was', 'what', 'offshoot', 'whom.', 'and', 'recipe,', 'in', 'when', 'finish.', 'usual', 'remember', 'couldn’t', 'slightly', 'old', 'the', 'its', 'wonder', 'custody,', 'kicked', 'uncertain', 'globe', 'getting', 'last', 'worth', 'i', 'lane', 'word).', 'crew', 'visceral', 'bad', 'm:i', 'called', 'on', 'though,', 'his', 'ethan’s', 'by', 'some', 'a', 'imf', 'formed', 'long,', 'does', 'lane.', 'out', 'an', 'complexity'}
# Document 4: {'lots', 'claws', 'but', 'meteorite', 'being', 'since', 'impoverished', 'very', 'maintaining', 'too', 't’challa’s', 'refreshing', 'used', 'feel', 'main', 'not', 'klaue,', 'while', 'there’s', 'killer,', 'it', 'bond,', 'weapons.', 'about', 'third', 'iron', 'like', '(yes,', 'this).', 'world.', 'far', 'everything', 'traditional', 'prologue', 'it’s', 'message.', 'first', 'he', '(i', 'are', 'of', 'death', 'that,', 'untimely', 'imbued', 'blossom', 'to', 'developed', 'this', 'clothing,', 'is', 'isn’t', 'simply', 'things', 'klaue', 'batman', 'from', 'panther,', 'fiendish', 'marvel', 'following', 'secret', 'story,', 'full.', 'dancing,', 'superhuman', 'with', 'also', 'wakanda’s', 'fights', 'king', 'times,', 'make', 'interesting', 'female', 'rest', 'justice.', 'country.', 'black', 'only', 'technology', 'which).', 'develop', 'and', 'father’s', 'in', 'purple', 'as', 'moral', 'forget', 'the', 'wakanda', 'its', 'composite', 'unfortunate', 'there', 'civilisation', 'unfortunately', 'strength', 'ulysses', 'new', 'reveal', 'man', 'threatens', 'ancient', 'task', 'previous', 'mystic', 'world', 'metal', 'film', 't’challa', 'colourful', 'high-tech', 'just', 'nicked', 'african', 'sexism)', 'long.', 'hit', 'posing', 'film.', 'characters,', 'non-whiteness,', 'has', 'wit.', 'bring', 'kingdom', '(spears,', 'less', 'his', 'that', 'by', 'a', 'some', 'ways', 'so', 'an'}
